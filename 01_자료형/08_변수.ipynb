# %%
# 변수는 어떻게 만드는가

a = 1
b = "python"
c = [1, 2, 3]

# %%
# 변수명 규칙

# 1. 영문자, 숫자, 언더스코어(_)로 구성
# 2. 숫자로 시작할 수 없음
# 3. 대소문자 구분
# 4. 예약어는 변수명으로 사용할 수 없음
# 5. 파이썬 키워드 사용 불가
# 6. 공백 문자 포함 불가
# 7. 특수 문자 포함 불가
# Out:
# 1

# %%
# list 변수

[a, b] = ["python", "life"]
print(a)
print(b)
# Out:
# python
# life
