# %%
# pip install

# !pip install SomePackage

# %%
# pip install 패키지명
# pin uninstall 패키지명
# pip install 패키지명==버전    - 특정 버전을 설치
# pip list - 설치된 패키지 리스트 확인

# %%
# !pip install Faker
# Out:
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    --------------------- ------------------ 1.0/2.0 MB 10.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 11.2 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    -------------------- ------------------- 1/2 [Faker]
#    -------------------- ------------------- 1/2 [Faker]
#    -------------------- ------------------- 1/2 [Faker]
#    -------------------- ------------------- 1/2 [Faker]
#    -------------------- ------------------- 1/2 [Faker]
#    -------------------- ------------------- 1/2 [Faker]
#    -------------------- ------------------- 1/2 [Faker]
#    -------------------- ------------------- 1/2 [Faker]
#    -------------------- ------------------- 1/2 [Faker]
#    -------------------- ------------------- 1/2 [Faker]
#    -------------------- ------------------- 1/2 [Faker]
# ...

# %%
# from faker import *
# from faker import Faker
import faker

# fake = Faker()
# fake.name()
# fake.address()

# for _ in range(10) :
#     print(fake.name())

# a = faker.Faker()
# a.name()
